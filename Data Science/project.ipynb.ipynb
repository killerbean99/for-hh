# %%
# Run this cell - Запустите эту ячейку SHFT+Enter
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
data = pd.read_excel('.xlsx', sheet_name='vv_ved_21_22_1')

# %%
data
# Out:
#           Lastname  Firstname  Username Study Format Department  \
# 0        Жуманбаев   Темирлан     27309  Бакалавриат  ITAC-1901
# 1        Ногайбаев      Димаш     27522  Бакалавриат  ITAC-1901
# 2        Сапарғали      Алмаз     27721  Бакалавриат  ITAC-1901
# 3          Докшина  Анастасия     27785  Бакалавриат  ITAC-1901
# 4         Қанатұлы    Нұролла     28214  Бакалавриат  ITAC-1901
# ...            ...        ...       ...          ...        ...
# 34354  Кадырханова      Лаура     27078  Бакалавриат   JUR-1902
# 34355        Ағман      Рабия     27079  Бакалавриат   JUR-1902
# 34356         Әшім  Таңшолпан     27080  Бакалавриат   JUR-1901
# 34357    Алмасова       Диана     28400  Бакалавриат   JUR-1901
# 34358     Мамедова      Лейла     28402  Бакалавриат  JUR-1903R
#
#                                               Coursename      Кафедра  \
# 0      13201 AR/VR technologies (Абылгазы А.А.) 2021-...   Кафедра КИ
# ...

# %%
# Your code goes here
data.head()
# Out:
#     Lastname  Firstname  Username Study Format Department  \
# 0  Жуманбаев   Темирлан     27309  Бакалавриат  ITAC-1901
# 1  Ногайбаев      Димаш     27522  Бакалавриат  ITAC-1901
# 2  Сапарғали      Алмаз     27721  Бакалавриат  ITAC-1901
# 3    Докшина  Анастасия     27785  Бакалавриат  ITAC-1901
# 4   Қанатұлы    Нұролла     28214  Бакалавриат  ITAC-1901
#
#                                           Coursename     Кафедра  \
# 0  13201 AR/VR technologies (Абылгазы А.А.) 2021-...  Кафедра КИ
# 1  13201 AR/VR technologies (Абылгазы А.А.) 2021-...  Кафедра КИ
# 2  13201 AR/VR technologies (Абылгазы А.А.) 2021-...  Кафедра КИ
# 3  13201 AR/VR technologies (Абылгазы А.А.) 2021-...  Кафедра КИ
# 4  13201 AR/VR technologies (Абылгазы А.А.) 2021-...  Кафедра КИ
#
#    РК1 (Ведомость)  РК2 (Ведомость)  РКсрд (Ведомость)  \
# 0         95.74405         95.58974           95.66690
# 1         95.50000         99.50000           97.50000
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [38], in <module>
# ----> 1 departments=data.Coursename.unique().index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
# Your code goes here

# Put your solution code here


for i in len(data):
    if(data.Department[i]==)
    
    
    
    
def stratified(data,size,percent):
    dstr=pd.DataFrame()
    k1=0
    k2=0
    for i in np.arange(0,len(data),1):
        if(k1==(int)(size*percent)):break
        num=np.random.randint(0,len(data))
        if(data.loc[num].sex=='F'):
            k1=k1+1
            dstr=dstr.append(data.loc[num],ignore_index=True)

    for i in np.arange(0,len(data),1):
        if(k2==size-(int)(sizepercent)):break;
        num=np.random.randint(0,len(data))
        if(data.loc[num].sex=='M'):
            k2=k2+1
            dstr=dstr.append(data.loc[num],ignore_index=True)


    return dstr

# %%
group_name="IT2-2006"
data2=data[data['Department']==group_name]

# %%
df=pd.DataFrame()
df_not_languages=pd.DataFrame()
df_languages=pd.DataFrame()
df=df.append(data2,ignore_index=True)

df_n_l= data2[data2['Кафедра']!='Кафедра Языков']
df_l = data2[data2['Кафедра']=='Кафедра Языков']
df_not_languages=df_not_languages.append(df_n_l,ignore_index=True)
df_languages = df_languages.append(df_l,ignore_index=True)
# Out:
# C:\Users\Nurseit\AppData\Local\Temp\ipykernel_10180\3139420373.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(data2,ignore_index=True)
# C:\Users\Nurseit\AppData\Local\Temp\ipykernel_10180\3139420373.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_not_languages=df_not_languages.append(df_n_l,ignore_index=True)
# C:\Users\Nurseit\AppData\Local\Temp\ipykernel_10180\3139420373.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_languages = df_languages.append(df_l,ignore_index=True)

# %%
df_not_languages
# Out:
#         Lastname  Firstname  Username Study Format Department  \
# 0        Ильинов      Ренат     28617  Бакалавриат   IT2-2006
# 1       Желудков     Максим     28621  Бакалавриат   IT2-2006
# 2       Колесник       Иван     28642  Бакалавриат   IT2-2006
# 3       Жанатаев    Оразбек     28812  Бакалавриат   IT2-2006
# 4     Жарылхасын       Қуат     29530  Бакалавриат   IT2-2006
# ..           ...        ...       ...          ...        ...
# 127     Утебасов     Даулет     29543  Бакалавриат   IT2-2006
# 128      Итемген  Нұрдәулет     29544  Бакалавриат   IT2-2006
# 129   Сапаралиев     Бегжан     29545  Бакалавриат   IT2-2006
# 130    Шакиртова     Медина     29546  Бакалавриат   IT2-2006
# 131  Жексенкадыр      Елара     29624  Бакалавриат   IT2-2006
#
#                                             Coursename      Кафедра  \
# 0    13203 Algorithmization and Programming (Токано...   Кафедра КИ
# 1    13203 Algorithmization and Programming (Токано...   Кафедра КИ
# ...

# %%
df_languages
# Out:
#        Lastname  Firstname  Username Study Format Department  \
# 0        Ергали      Олжас     29531  Бакалавриат   IT2-2006
# 1      Каратаев     Атабек     29535  Бакалавриат   IT2-2006
# 2    Сапаралиев     Бегжан     29545  Бакалавриат   IT2-2006
# 3   Жексенкадыр      Елара     29624  Бакалавриат   IT2-2006
# 4        Таймас   Нұрсейіт     29533  Бакалавриат   IT2-2006
# 5       Шарипов      Карим     29534  Бакалавриат   IT2-2006
# 6    Сарсенбаев   Дамирбек     29536  Бакалавриат   IT2-2006
# 7      Утебасов     Даулет     29543  Бакалавриат   IT2-2006
# 8      Жанатаев    Оразбек     28812  Бакалавриат   IT2-2006
# 9     Караманов      Элдар     29537  Бакалавриат   IT2-2006
# 10      Итемген  Нұрдәулет     29544  Бакалавриат   IT2-2006
# 11    Шакиртова     Медина     29546  Бакалавриат   IT2-2006
# 12     Колесник       Иван     28642  Бакалавриат   IT2-2006
# 13      Төкенов    Асанәлі     29542  Бакалавриат   IT2-2006
# ...

# %%
df_not_languages
# Out:
#         Lastname  Firstname  Username Study Format Department  \
# 0        Ильинов      Ренат     28617  Бакалавриат   IT2-2006
# 1       Желудков     Максим     28621  Бакалавриат   IT2-2006
# 2       Колесник       Иван     28642  Бакалавриат   IT2-2006
# 3       Жанатаев    Оразбек     28812  Бакалавриат   IT2-2006
# 4     Жарылхасын       Қуат     29530  Бакалавриат   IT2-2006
# ..           ...        ...       ...          ...        ...
# 127     Утебасов     Даулет     29543  Бакалавриат   IT2-2006
# 128      Итемген  Нұрдәулет     29544  Бакалавриат   IT2-2006
# 129   Сапаралиев     Бегжан     29545  Бакалавриат   IT2-2006
# 130    Шакиртова     Медина     29546  Бакалавриат   IT2-2006
# 131  Жексенкадыр      Елара     29624  Бакалавриат   IT2-2006
#
#                                             Coursename      Кафедра  \
# 0    13203 Algorithmization and Programming (Токано...   Кафедра КИ
# 1    13203 Algorithmization and Programming (Токано...   Кафедра КИ
# ...

# %%
df["ФИО"] = df["Lastname"].astype(str) + " " + df["Firstname"].astype(str)

# %%
coursnames = df.Coursename.unique()
coursnames
# Out:
# array(['13203 Algorithmization and Programming (Токанов О.С.) 2021-2022/1',
#        '13205 Introduction to Robotics (Coursera ..) 2021-2022/1',
#        '13215 Programming in Python language (Coursera ..) 2021-2022/1',
#        '13216 Databases Design. Introduction to SQL (Козина Л.А.) 2021-2022/1',
#        '13430 Discrete mathematics (Кулпешов Б.Ш.) 2021-2022/1',
#        '13572 Physical Culture () 2021-2022/1',
#        '13636 Pre-Intermediate (Абдулина М.Е.) 2-course 2021-2022/1',
#        '13639 Pre-Intermediate (Даулеткызы К.) 2-course 2021-2022/1',
#        '13643 Pre-Intermediate (Керейбаева А.) 2-course 2021-2022/1',
#        '13644 Pre-Intermediate (Молдасанова А.А.) 2-course 2021-2022/1',
#        '13647 Pre-Intermediate (Рахимжанова М.М.) 2-course 2021-2022/1',
#        '13650 Pre-Intermediate (Шаршова Р.) 2-course 2021-2022/1',
#        '13651 Intermediate (Аксамбаева А.) 2-course 2021-2022/1',
#        '13652 Intermediate (Атжанова Т.) 2-course 2021-2022/1',
# ...

# %%
id_of_students=df['Username'].unique()
number_of_students=len(id_of_students)
full_names_of_students=df['ФИО'].unique()
number_of_students
# Out:
# 22

# %%
final2=pd.DataFrame()

# %%
A = np.arange(1,number_of_students+1)

# %%
df_languages
# Out:
#        Lastname  Firstname  Username Study Format Department  \
# 0        Ергали      Олжас     29531  Бакалавриат   IT2-2006
# 1      Каратаев     Атабек     29535  Бакалавриат   IT2-2006
# 2    Сапаралиев     Бегжан     29545  Бакалавриат   IT2-2006
# 3   Жексенкадыр      Елара     29624  Бакалавриат   IT2-2006
# 4        Таймас   Нұрсейіт     29533  Бакалавриат   IT2-2006
# 5       Шарипов      Карим     29534  Бакалавриат   IT2-2006
# 6    Сарсенбаев   Дамирбек     29536  Бакалавриат   IT2-2006
# 7      Утебасов     Даулет     29543  Бакалавриат   IT2-2006
# 8      Жанатаев    Оразбек     28812  Бакалавриат   IT2-2006
# 9     Караманов      Элдар     29537  Бакалавриат   IT2-2006
# 10      Итемген  Нұрдәулет     29544  Бакалавриат   IT2-2006
# 11    Шакиртова     Медина     29546  Бакалавриат   IT2-2006
# 12     Колесник       Иван     28642  Бакалавриат   IT2-2006
# 13      Төкенов    Асанәлі     29542  Бакалавриат   IT2-2006
# ...

# %%
subjects_are_not_languages
for i in range(len(coursnames)):
    if(coursnames[i][6:22] != "Pre-Intermediate" and coursnames[i][6:18] != "Intermediate" and coursnames[i][6:18] != "Intermediate"):
        final.insert(n, coursnames[i], [], True)
        n+=1

# %%
final2['№'] = A
final2['ID'] = id_of_students
final2['ФИО'] = full_names_of_students

# %%
count = 0  

for i in range(len(df_not_languages.Coursename.unique())):
    s=[]
    s1=[]
    s2=[]
    s3=[]
    for j in range(number_of_students):
        s.append(df_not_languages['РК1 (Ведомость)'][count])
        s1.append(df_not_languages['РК2 (Ведомость)'][count])
        s2.append(df_not_languages['Финальный Экзамен (Ведомость)'][count])
        s3.append(round(((df_not_languages['РК1 (Ведомость)'][count]+df_not_languages['РК2 (Ведомость)'][count])*0.3)+(df_not_languages['Финальный Экзамен (Ведомость)'][count]*0.4)))
        count+=1
    final2[df_not_languages.Coursename.unique()[i]+' '+'РК1 (Ведомость)']=s
    final2[df_not_languages.Coursename.unique()[i]+' '+'РК2 (Ведомость)']=s1
    final2[df_not_languages.Coursename.unique()[i]+' '+'Финальный Экзамен (Ведомость)']=s2
    final2[df_not_languages.Coursename.unique()[i]+' '+'Итог']=s3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [118], in <module>
#      10     s1.append(df_not_languages['РК2 (Ведомость)'][count])
#      11     s2.append(df_not_languages['Финальный Экзамен (Ведомость)'][count])
# ---> 12     s3.append(round(((df_not_languages['РК1 (Ведомость)'][count]+df_not_languages['РК2 (Ведомость)'][count])*0.3)+(df_not_languages['Финальный Экзамен (Ведомость)'][count]*0.4)))
#      13     count+=1
#      14 final2[df_not_languages.Coursename.unique()[i]+' '+'РК1 (Ведомость)']=s
#
# ValueError: cannot convert float NaN to integer

# %%
final2
# Out:
#      №     ID                   ФИО  \
# 0    1  28617         Ильинов Ренат
# 1    2  28621       Желудков Максим
# 2    3  28642         Колесник Иван
# 3    4  28812      Жанатаев Оразбек
# 4    5  29530       Жарылхасын Қуат
# 5    6  29531          Ергали Олжас
# 6    7  29532  Жаксиликов Нурдаулет
# 7    8  29533       Таймас Нұрсейіт
# 8    9  29534         Шарипов Карим
# 9   10  29535       Каратаев Атабек
# 10  11  29536   Сарсенбаев Дамирбек
# 11  12  29537       Караманов Элдар
# 12  13  29538  Назарбекұлы Бауыржан
# 13  14  29539          Амалбек Аида
# 14  15  29540    Мусабеков Нурлыбек
# 15  16  29541      Абдиади Розалина
# 16  17  29542       Төкенов Асанәлі
# 17  18  29543       Утебасов Даулет
# 18  19  29544     Итемген Нұрдәулет
# 19  20  29545     Сапаралиев Бегжан
# 20  21  29546      Шакиртова Медина
# 21  22  29624     Жексенкадыр Елара
#
#     13203 Algorithmization and Programming (Токанов О.С.) 2021-2022/1 РК1 (Ведомость)  \
# ...

# %%
round(s3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [117], in <module>
# ----> 1 round(s3)
#
# TypeError: type list doesn't define __round__ method

# %%
df_not_languages['Итог']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Итог'
#
# ...

# %%
final2
# Out:
#      №     ID                   ФИО  \
# 0    1  28617         Ильинов Ренат
# 1    2  28621       Желудков Максим
# 2    3  28642         Колесник Иван
# 3    4  28812      Жанатаев Оразбек
# 4    5  29530       Жарылхасын Қуат
# 5    6  29531          Ергали Олжас
# 6    7  29532  Жаксиликов Нурдаулет
# 7    8  29533       Таймас Нұрсейіт
# 8    9  29534         Шарипов Карим
# 9   10  29535       Каратаев Атабек
# 10  11  29536   Сарсенбаев Дамирбек
# 11  12  29537       Караманов Элдар
# 12  13  29538  Назарбекұлы Бауыржан
# 13  14  29539          Амалбек Аида
# 14  15  29540    Мусабеков Нурлыбек
# 15  16  29541      Абдиади Розалина
# 16  17  29542       Төкенов Асанәлі
# 17  18  29543       Утебасов Даулет
# 18  19  29544     Итемген Нұрдәулет
# 19  20  29545     Сапаралиев Бегжан
# 20  21  29546      Шакиртова Медина
# 21  22  29624     Жексенкадыр Елара
#
#     13203 Algorithmization and Programming (Токанов О.С.) 2021-2022/1 РК1 (Ведомость)  \
# ...

# %%
for i in range(len(coursnames)):
    final2[coursnames[i]]=(func(final,coursnames[i],i))

# %%
def func(final,coursname_in_f,i):
    for i in range(len(df)):
        if()
    
    return rk1

# %%
writer = pd.ExcelWriter('output.xlsx')
final2.to_excel(writer)
writer.save()

# %% [markdown]
# What NaNs are you going to restore - Answer as a text

# %%
final2.shape[0]+1
# Out:
# 23

# %%
final
# Out:
# Empty DataFrame
# Columns: [№, ФИО, ID, 13203 Algorithmization and Programming (Токанов О.С.) 2021-2022/1, 13205 Introduction to Robotics (Coursera ..) 2021-2022/1, 13215 Programming in Python language (Coursera ..) 2021-2022/1, 13216 Databases Design. Introduction to SQL (Козина Л.А.) 2021-2022/1, 13430 Discrete mathematics (Кулпешов Б.Ш.) 2021-2022/1, 13572 Physical Culture () 2021-2022/1, 13678 Профессиональный казахский язык (Турусбекова А.Е.) 2021-2022/1]
# Index: []

# %%
# Out:
# C:\Users\Nurseit\AppData\Local\Temp\ipykernel_3796\470922821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FIO'] = df['Lastname'].str.cat(df['Firstname'], sep =" ")

# %%
df_marks = df_marks.append(new_row, ignore_index=True)
# Out:
#           Lastname  Firstname  Username Study Format Department  \
# 330        Ильинов      Ренат     28617  Бакалавриат   IT2-2006
# 331       Желудков     Максим     28621  Бакалавриат   IT2-2006
# 335       Колесник       Иван     28642  Бакалавриат   IT2-2006
# 370       Жанатаев    Оразбек     28812  Бакалавриат   IT2-2006
# 475     Жарылхасын       Қуат     29530  Бакалавриат   IT2-2006
# ...            ...        ...       ...          ...        ...
# 32673     Утебасов     Даулет     29543  Бакалавриат   IT2-2006
# 32674      Итемген  Нұрдәулет     29544  Бакалавриат   IT2-2006
# 32675   Сапаралиев     Бегжан     29545  Бакалавриат   IT2-2006
# 32676    Шакиртова     Медина     29546  Бакалавриат   IT2-2006
# 32677  Жексенкадыр      Елара     29624  Бакалавриат   IT2-2006
#
#                                               Coursename         Кафедра  \
# 330    13203 Algorithmization and Programming (Токано...      Кафедра КИ
# ...

# %%
final.ФИО[0]=df.FIO[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
